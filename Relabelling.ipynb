# %%
import textwrap
import pickle

import pandas as pd

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

from IPython.display import IFrame, HTML, clear_output

import NL_helpers
import NL_topicmodels

# %%
# Run cell to reload NL_helpers and NL_topicmodels if they have been changed.
from importlib import reload
reload(NL_helpers)
# Out:
# <module 'NL_helpers' from '/home/joshua/Documents/Academic/MADS/DATA601/NL_helpers.py'>

# %% [markdown]
# ### What are my criteria?
# #### Original:
# - Readable:
#     - Options: y/n
#     - Criterion: Whether, on reading just the OCR, I could decypher what was meant (even if this required a lot of effort). No comparison with original images made.
# - Philosophy:
#     - Options: y/n
#     - Criterion: somewhat messy. Shift between 'do I want this to come out of the classifier?', 'am I interested in this?', 'does this mention someone who I already have reason to think of as engaged in 'philsophical activity' (e.g. reports of Josiah Royce in Australia, which I wouldn't otherwise have added). Lots of material on relationship between religion and science/metaphysical speculations. Politics largely avoided unless argued from something like first principles as I didn't want a corpus full of political speeches (which seem to be pretty well represented in the PPNODP dataset (eek, new acronym).
#     - Issues: This is too idiosyncratic. Will suggest a modification in the next section.
# - Philosophy Type:
#     - Options: 'r': religion-science; 'e': ethics, including some politics; 'm': epistemology-metaphysics; 'o': other.
#     - Criteria:
#         - 'r': (139 total). Does the piece reason about, say, the relationship between ideas of creation and evolution, or whether religious belief can be sustained against 'modern thought' in general. This will include reports of sermons that touch on these issues, public debates, lectures by church of 'free thought' activists. I've also included, e.g., material by theosophists.
#         - 'm': (13 total) Does the piece touch on abstract metaphysical or epistemological issues without reference to the relationship between religion and modern science/history. Includes
#         - 'e':(94 total). Broadly ethics and politics (94 total). Discussions of whether certain things are virtues or vices (e.g. curiosity). Conceptual discussions of politics (although not more straight forward arguments between liberals and others which do not go into the foundations of their principles). For instance, an account of papal CST statement (look up which), which argues that the pope at the time is confused about what 'socialism' means when denouncing it (as the rest of the statement actually defends a view which would be called 'socialist' in the context of the discussions happening in NZ (and perhaps the anglosphere more broadly?)).
#         - 'o': (51 total) I didn't think others applied. For instance: report of sitting in on philosophy lectures at Harvard. Discussions of the nature of the university etc.
#     - Issues:
#         - Most of my 'false negatives' comes from the 'o' category.
#         - 'm' not widely used. Included Frankland on 'mind-stuff'. It's arguable that 19th century idealism is, broadly speaking, about reconcilling 'religious' principles with new scientific and historical knowledge. But it's not at all explicit in the kind of thing Frankland does in his 'mind-stuff' material. Some theosophical speculations carried out without explicit reference to 'modern developments' are also included. A bit of a hodge-podge.
#         - The 'e' crossover with 'm' and 'r'. It's more common in this kind of material than in, say, contemporary academic philosophy, to go straight for an ethical or political conclusion from a set of metaphysical claims. The 'piecemeal' approach favoured by analytic philosophy has definitely not taken root here (unsurprisingly - it's a much later development.
# - Writing Type:
#     - Options:
#         - 'p': A report of a public events or printing of an address delivered to an audience. Includes sermons, debates, lectures, etc.
#         - 'l': A letter to the editor.
#         - 'f': a first-order piece of philosophy by an author for the newspaper or printed from somewhere else.
#         - 'r': book review.
#     - Issues:
#         - I haven't actually used this for any kind of classifier.
# - NZ author?
#     - Options: y/n
#     - Criterion: Does it look to me like the author was based in NZ or is a known NZ figure? (e.g. Stout writing from Sydney is fine). No if, e.g., it is clearly a republishing of something from elsewhere.
#     - Issue: almost everything is NZ. This is not useable for a classification scheme.
#
#
# #### Second attempt:
# - Readable:
#     - Changes: will simply double check.
# - Philosophy:
#     - Changes: I should include more political discussions and let the more fine-grained distinctions regarding philosophy type do more work for me.
#     - Be more careful with large pieces in which only a bit is 'philosophy'.
#     - New criterion: 'Philosophical', for the purpose of constructing this corpus, is reflection on fundamentals. Philosophical discourse will make some appeal to first principles or argue that there are no such principles. It will not merely deal with current political scandals or just make a series of claims from within a (e.g.) theological framework.
# - Philosophy Type:
#     - 'r': Same as before: but more explicitly religion in light of modern science (esp. evolution), history (esp. 'higher criticism'). Include theosophical works here and 'free thought' lectures. Include metaphysical work
#     - 'e': ethics and politics. Include disputes over nature of education system here.
#     - 'o': Anything which doesn't fit in those two.
# - Writing Type and NZ/non-NZ:
#     - I think these are mostly fine (but double check)
#     - Writing type: add to non-philosophical writing.
#
#
#
# ### Other issues:
# - The 'philosophy' classification tends to be applied to very short articles (and even empty ones), to articles in te reo, and to articles unreadable because of bad OCR.
#     - Solution: Filter out the readable/unreadable by making a classifier for this first. Ignore issue of te reo articles as this can be dealt with later.
# - Missclassified articles are often articles which *contain* philosophical writing within a much larger piece (often these are very long articles by the editor of the newspaper touching on many topics.
#     - Solution: Exclude these from the labelled (philosophy) dataset unless the majority of the article is 'philosophy'.
# - I've imagined this as a hierarchical system, but it's possible that the, e.g. public event vs non public-event classifier would work better if I also labelled non-philosophy articles with writing types.
#
# ### Updates to use of NB classifiers
# 1. Readable/Non-Readable model
# 2. Philosophy/Non-Philosophy model
#     * feed the resulting 'philosophy' corpus into topic model.
# 3. Religion-Science/Other model.
#     * feed the resulting 'religion-science' corpus into topic model.
# 4. Do anything with 'public lecture?'... could do a 'letter classifier'?

# %%
labelled_with_text = pd.read_pickle('pickles/classified_with_text_as_list_df.pickle')

# %%
labelled = pd.read_pickle('pickles/classified_df.pickle')

# %%
def print_text_index_only(index, dataframe):
    """
    Given index, return string containing heading and body text.
    Assumes dataframe contains a 'Text' column containing lists of
    strings as entries as well as 'Title'. Works out newspaper and
    date from index.
    """
    newspaper = index[0:index.find('_')]
    date = index[index.find('_')+1:index.find('_')+9]
    title = "Not given by labelled df."
    text_blocks = dataframe.loc[index, 'Text']
    wrapped_blocks = []
    for block in text_blocks:
        wrapped_string = textwrap.fill(block, width=80)
        wrapped_blocks.append(wrapped_string)
    text = '\n\n'.join(wrapped_blocks)
    article_string = f'{title}\n{newspaper} - {date}\n\n{text}'

    print(article_string)

# %%
checked = []

# %%
checked = checked[0:-2]

# %%
exit = False
i = 0
while exit == False:
    print('?') #For some reason this statement is required for the next print statements to function.
    index = labelled_with_text.index[i]
    print(f"Current Classification = \n{labelled.loc[index]}")
    
    if index not in checked:
        print_text_index_only(index, labelled_with_text)
    
        change_decision = input('Change? (y/n) >')
        if change_decision == 'y':    
            labelled.loc[index] = NL_helpers.classify_text_v2()        

        checked.append(index)
    i+=1
    clear_output()
# Out:
# ?
# Current Classification =
# Readable                                                        True
# Philosophy                                                      True
# Philosophy Type                                                    o
# Writing Type                                                       p
# NZ                                                              True
# the exception that the upper ones will have single sheets of glass in the
# frames, while below there will be six. The root' will be covered with corrugated
# iron, the front will bo bonvdedand rusticated with pilasters at each side,
# strings, covnicesir.nl a parapet. Tho whole of the ouUilc walls will bo painted.
# Tenders for this work will be received by the General Government up to noon to
# day, -each fender to be accompanied by a deposit oi' £25. The plans and
# spoeifie.it ions may be seen tit the Provincial Engineer's office. Shipping
# Master,-— We believed that this matter had been already ?ofc at rest, but recent
# events would show that Hitch is not tho case. Surely when there arc some
# luui.lrcdsof men eon i-tnniiy sailing out of this port, and when coni
# nj'.nKl'iTs of steam and sailing ships arc oonLiiniily inquiring and searching
# for sexmeu, the least concession that can bo miid.i by the Cus toms' authorities
# is to render aid when it is so generally asked. "Wo deem it n mo ?t anomalous ■
# state of auiiirs, thai Captain Wright, or any otlic" I shipmaster, should have
# occasion to rummage about town for men to work his ship, when ho . is bound lo
# pay engaging fees at (he Cu;.!o:n ; I louse. On his return from Panama, Captain
# <>. Wright will doubtless think twice before he I again pays oft" any of his
# people in Wel : lington. It has boon noticed in a previous i. issue Mint the
# Mercantile Marine Act, adopted in ' Now Zealand in 185(5, gives power to the
# colonial government to appoint persons to engage and ■, discharge seamen. The
# important; interests of I shipmasters and sailors in this respect have had J,
# immediate attention paid to them in other ', colonies when pointed out and dot-
# irod, but in New Zealand — behind hand comparatively in I almost every
# adm'inistnitivo department, — a heavy c pressure from without van ulono set tho
# rusi.y , government machine in moliou. - S'l'E.YirEK Huntukss. — The st earner
# Huntress ■• has been dis.p.jscd of by tho Provincial (Jovern |- ment of
# llawke.-s' Ui\y — (lie purchaser behg Cap « fain Head of Po\erty 33ay, and the
# pi'.rcha=o ft money £300. There is some chance of her bein^ T, kept in tho
# Napier and l'owrly l!ay trade. p A .SFinr.YiuxE Piu-iCiavvioy. — Amount Mie *
# uses t-.» which tho Atlantic cable has been put j..- II one whi'.-h wonKl Imnlly
# be anlicij. iLeil. A cor "' respondent communicates to us, a telegram which he
# received from a patient who, being seized with :fc a renewed attack of an
# illness from which ho Iml y sull'erod in this coun'ry. anil for which ho bad
# been successfully treated, telegraphed to his :- old Die.Ucnl al\VniV.mt for
# directions. These i- were returned by the same channel without >f delay, and we
# hope, they may have prospered, and :. that the proper remittance will follow by
# an e.ir'.y d packet-. Tin's prescription will rank among the i, curiosities of
# telegraphy. — The. LanciJ. [<i A lticscuK fjiom Drowning.-- The 1S t cV>i 0
# Colonist of (lie ULli iust s:n*.— A hn\ Jinnipc Do whim, about nine years of
# ago, enngaged mind ■s, ing cows near tho Haven ftond, on Sunchy last il hid gone
# out to tho point of the small jelty oppo ,n site the offices of Mr. John licit-,
# and had fuller ie into tho water. Mr Odling, shoemaker, was puss of ing at the
# time on his way to church, arid saw fclv in lad, and immediately ran up tho
# jetty, and ut dressed as he was, plunged into tho valor «n< )g saved the boy,
# who was just turning over on hi to back nnr-I losing hid senses, when Mr.
# Otllinj rescued him.
#
# AiufT.sr ny -v Ha.v If ac. — On Wednesday last says tho llawke's Bay Herald,
# Maika, a second ary Hau Hau chief, who escaped for a time to the Maungaharuru
# liimges, was apprehended at a sheep station by a young half caste named James
# crossing tho Mohak i river at the church ford, you gradually ascend for about
# five miles, until you come lo the. deserted kainga To Hnrolo, which belonged to
# the late chief .Wangi hiroa. About three miles further on you como to another
# deserted .Tlau Hau kainga, Waiparati You now go through a bush track for about
# nine miles until you come to a sharp-pointed hill called Tunvnga Kuma—lhc
# farthest pniut to which the late expedition marched, ilero you dceccnu rnpidlv
# for about three miles, when you come, to the valley of the Waipanga : you cross
# this river twice here, and travel on in the *uno direction in which the river is
# running for about ten mile, over bush and fi'rn hills, keeping an average
# distance of two miles from it, until yon come again to the river at Tarawcra
# (Nikora's pa). You continue your march over bush, lern, and grass hills,
# crossing several large stream?, for eleven miles further, when you come to the
# edge of the Taupo plains. Along the whole road from Waiparili to the edge of tho
# plains you come across deserted kaingas and plantations, showing that to within
# the last few months the country h:i3 been thickly populated. 3u-om the southern
# end of tho plains to lake Tuupo, a diM.mec oi' ii bout, twenty-six miles, you
# travel over nothing but. level pumice-stone land, with a few lu^oc'is of "rass
# hen- and t-here, and a little manuka scrub, Ido not think that this land \vou!<l
# carry one sheep to the ten acres ; and the only ex ception lo this j : v>orne.-s
# of soil is where a ?lre:im run? aero.--.* tho plains:, or on (he ctlye. of a
# small bush about lew miles on the Napier side of Lake Taupo. On iiie shores of
# the Jake the soil appears pr< tly C!,MOfl, growing potatoes and other
# vegetable:; pr.'fciy woll. The lake itself is :i very ! line one, with a"
# beautiful sandy s'lore. On ih> j p.mlh-easl-, east, and nnrlh-e.iM shares (which
# 1. j vi-itcd) there tn-e several kainga-, the na'ivos of (which nre very
# h.sspit-.ibl' 1 , and aro r.l.iuueh ' Kawanutaugas :' tho:<e on the wc^lem
# s-horc ;uv Him li-.uvs, hut are ihhv ra'hui' h.kcwarm toward.-; i ihoir U:hi
# lJiUinod. From the northern e-xiv.-mi'.x 1 of tho lake, the '\V.iik:-.to river
# il;iws in si l:o.!y of | water about two-lliiivl.s ilie l=ro;i'.lih of tl).> en
# j trance tv Nnpi'' 1 . 1 harbor. Tlie nnd to Aurkh.niv cro^ej i)ic vivcr jn.-t
# In-re. The nos-th ami wenltvn bhnivs of tho lake a.-c more hilly than lho
# oilier, iuiil t-lie J.md, I hear, is of no baler ! cp'.ulily. ■ | Tin;
# 11oii?o:,' ?.ri::.r^r.TAT J .--'l'iie ll r v\i. C<yt:l ! Tnr.rs of tin- 7!b
# inst. s-.iys :— " Wli.it has br/oir.y ' of the m'-ney of lite money sub-'cri'icd
# :_o lil.vi-.il'y ! iowariis the ' L\il>.-'on ILemr.rial ?' W« a«'i: iv- I
# dn.'-cil lo a-k tl-.is question, as s 'veral app'.i.-a'iioi^ lnvn been made to
# r.s lately i'y ]vw-f.ics «!io eon liibuti'ii, and who very nalui-llv dcm-.nvl
# lU'.t. Mhe orivinal obj-.-ct should citlicr l>o cM-rii-d out, ' of that' tiv.'
# e:';<!i pubscrihed should be refunded. ! ' We iiisvo lately labored under the
# idoa (a falla i rious one app.lrenlly) that the latter coir.'so h-id long pinee
# been ndop-i-d. and we feel much sur \ pri::e. that it wa^ not as many web ago
# the niive menL fell thfouji, and wns em-rci-lly rogavded as [ one of tlio^e '
# skater of the world, officiates as M.0., ns well as to instruct tyros in
# thcigamo. The evolutions ho performs arc truly surprising, and show to what a
# pitch of perfection the art can be brought. We congratulate Messrs Sinclair and
# Mothersili, the proprietors, upon the vevy marked success which attended Jhc
# opening of their " rink" on Saturday, and hope that their endeavors to provido
# another source of Jimusemcnfc for tho rwMonts of this town will mrofc with largo
# and continuous patronage. TnE Hush to the Noktii.— Tho Wed Coasl Times of Pee.
# 11, says that that I lie rush Jo the northern diggings is setting in with a
# vengeance, as is endorsed hy the numbers which leave in every steamer bound to
# tho now celebrated TJiillcr district. The accounts that reach town from the
# vnriou? dig-jin^s, tell of packing-up nmonjjsi. the. minei'3, of whom hundred 3
# have fairly^taken tho gold distemper, and ure eager to bo gone. It is said llvit
# the bench. 5? lined with i travellers, ns many pivfer (o nv.*ko (lie jouvne.y
# overland rather than risk n sea voyage. Whist admit! in;; that the roporLs from
# the now rush arc decidedly encouraging, we would yet c.mtion fligiiers a^aiu-l
# over haslo in leaving payable ground to risk a campaign in a district; which is
# notorious for its patchy diameter. Tho Pukihi, loud as its praises were
# trumpeted, tuvnnd out a mere patch, and we hnvo very good reasons for believing
# that the workings nt Vox's Iliver — although, so far rich— will prove of limited
# extent,. Our last adviceo stated that all of the payable ground was taken up,
# and hundreds of men, in con- Je-]u.'ineo, -were compelled to go prospecting ;
# and, although il wa3 anticipated that fresh patches would be struck in tho
# vicinity, and towards the drey, such a hope h a mere hypothesis upon which it
# would bo most rash to take action. We have leurnt by bitter experience h.r.v
# much dis aster is likely to result from the sudden collap-.e of a diggings
# situated in such an ovJ -oi'-i he-way I country^us that of Paldiu and Fox's,
# where p-o --! visions' rule at famine prices, and from which vctrcat. is
# difficult. Again we urge up.'>n iniiK-s i who have the certainty of months of
# steady work I before them in tho settled district.-- oi' We.«lland, to pause yet
# awhile ere they, hy v ]»-ecipit.'te act, illustrate' the fable of 'The
# substiuiuo and the J shadow. 1 " !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~/.local/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-41316dee071d> in <module>
#       9         print_text_index_only(index, labelled_with_text)
#      10
# ---> 11         change_decision = input('Change? (y/n) >')
#      12         if change_decision == 'y':
#      13             labelled.loc[index] = NL_helpers.classify_text_v2()
#
# ~/.local/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~/.local/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:

# %%
len(checked)
# Out:
# 90

# %%
with open('pickles/labelled_v2_df_in_progress.pickle', 'wb') as outfile:
    pickle.dump((checked, labelled), outfile)

# %%
philoso_df = pd.read_pickle('pickles/nb2_philoso_df.tar.gz')

# %%
NL_helpers.add_title_and_date(philoso_df)
philoso_df = NL_helpers.remove_duplicates(philoso_df)

# %%
index_subset = philoso_df.index.to_series().sample(n=500)

# %%
interact(NL_helpers.html_text, index=index_subset, dataframe=fixed(philoso_df), boldface=fixed(None))
